# %%
import pandas as pd

# %%
data = {
    "station": ["Anand Vihar", "Rohini", "Dwarka"],
    "pollutant": ["PM2.5", "PM2.5", "PM10"],
    "value": [180, 140, 220],
    "timestamp": ["2026-05-20 09:00", "2026-05-20 09:00", "2026-05-20 10:00"]
}
df = pd.DataFrame(data)
df
# Out:
#        station pollutant  value         timestamp
# 0  Anand Vihar     PM2.5    180  2026-05-20 09:00
# 1       Rohini     PM2.5    140  2026-05-20 09:00
# 2       Dwarka      PM10    220  2026-05-20 10:00

# %%
df.head()
# Out:
#        station pollutant  value         timestamp
# 0  Anand Vihar     PM2.5    180  2026-05-20 09:00
# 1       Rohini     PM2.5    140  2026-05-20 09:00
# 2       Dwarka      PM10    220  2026-05-20 10:00

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   station    3 non-null      str
#  1   pollutant  3 non-null      str
#  2   value      3 non-null      int64
#  3   timestamp  3 non-null      str
# dtypes: int64(1), str(3)
# memory usage: 228.0 bytes

# %%
df.describe()
# Out:
#        value
# count    3.0
# mean   180.0
# std     40.0
# min    140.0
# 25%    160.0
# 50%    180.0
# 75%    200.0
# max    220.0

# %%
df.shape
# Out:
# (3, 4)

# %%
df["station"]
# Out:
# 0    Anand Vihar
# 1         Rohini
# 2         Dwarka
# Name: station, dtype: str

# %%
df[["station", "value"]]
df[df["pollutant"] == "PM2.5"]
df[df["value"] > 150]
# Out:
#        station pollutant  value         timestamp
# 0  Anand Vihar     PM2.5    180  2026-05-20 09:00
# 2       Dwarka      PM10    220  2026-05-20 10:00

# %%
df.to_csv("../data/raw/sample_aqi.csv", index=False)

# %%
df_loaded = pd.read_csv("../data/raw/sample_aqi.csv")
df_loaded
# Out:
#        station pollutant  value         timestamp
# 0  Anand Vihar     PM2.5    180  2026-05-20 09:00
# 1       Rohini     PM2.5    140  2026-05-20 09:00
# 2       Dwarka      PM10    220  2026-05-20 10:00
